# %%
# "============== 학습 설정 =============="
#required: definitely edit these!
dataset_path = './datasets/top_cat_256.zip'
resume_from = './pretrained/ffhq1024.pkl'
aug_strength = 0.0
train_count = 0
mirror_x = True
#mirror_y = False

#optional: you might not need to edit these
gamma_value = 50.0
augs = 'bg'
config = '24gb-gpu'
snapshot_count = 20

# %%
# !python train.py --gpus=1 --cfg=$config --metrics=None --outdir=./results --data=$dataset_path --snap=$snapshot_count --resume=$resume_from --augpipe=$augs --initstrength=$aug_strength --gamma=$gamma_value --mirror=$mirror_x --mirrory=False --nkimg=$train_count --kimg=1000
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 4,
#   "network_snapshot_ticks": 4,
#   "metrics": [],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "./datasets/top_stripe_256.zip",
#     "use_labels": false,
#     "max_size": 680,
#     "xflip": true,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 8,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 8
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
# ...

# %%
for i in range(512):
  # !python apply_factor.py -i {i} -d 10 --seeds 177 --ckpt /home/elicer/stylegan2-ada-pytorch/results/00000-top_cat_256-mirror-24gb-gpu-gamma50-kimg2000-bg-resumecustom/network-snapshot-002000.pkl /home/elicer/stylegan2-ada-pytorch/content/style1.pt --output /home/elicer/stylegan2-ada-pytorch/content/style-177/ --video
# Out:
# Loading networks from "/home/elicer/stylegan2-ada-pytorch/results/00000-top_cat_256-mirror-24gb-gpu-gamma50-kimg2000-bg-resumecustom/network-snapshot-002000.pkl"...
#
#     Checkpoint: /home/elicer/stylegan2-ada-pytorch/results/00000-top_cat_256-mirror-24gb-gpu-gamma50-kimg2000-bg-resumecustom/network-snapshot-002000.pkl
#     Factor: /home/elicer/stylegan2-ada-pytorch/content/style1.pt
#     Outpur Directory: /home/elicer/stylegan2-ada-pytorch/content/style-177/
#     Mode: seeds ([177])
#     Index: eigenvectors [0]
#     Truncation: 0.7
#     Video: True
#     Video Increments: 0.1
#
# Generate images for seed  177
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Saving image  /home/elicer/stylegan2-ada-pytorch/content/style-177/seed-177_index-0_degree-10.0.png
# ...
